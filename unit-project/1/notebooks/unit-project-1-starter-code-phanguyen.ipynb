# %% [markdown]
# # DS-SF-36 | Unit Project | 1 | Research Design | Starter Code

# %% [markdown]
# In this first unit project, you will create a framework to scope out data science projects.  This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ## Part A.  Evaluate the following problem statement:

# %% [markdown]
# > "Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and `activity score 1 = active user`, `0 = inactive user`) based on Hooli data from January-April 2015."

# %% [markdown]
# > ### Question 1.  What is the outcome?

# %% [markdown]
# Answer:
# Free-tier customers indicators: a pattern of free-tier customers who will covert to paying customers

# %% [markdown]
# > ### Question 2.  What are the predictors/covariates?

# %% [markdown]
# Answer: Demographic data collected at signup such as: age, gender, location, and profession
# & customer useage data such as: days since last log in, and activity score

# %% [markdown]
# > ### Question 3.  What timeframe is this data relevent for?

# %% [markdown]
# Answer: January-April 2015

# %% [markdown]
# > ### Question 4.  What is the hypothesis?

# %% [markdown]
# Answer: Hypothesis is the demographic & customer usage data can allow us to find out a pattern of free-tier customers who will covert to paying customers

# %% [markdown]
# ## Part B.  Let's start exploring our UCLA dataset and answer some simple questions:

# %%
import os
import pandas as pd

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

df = pd.read_csv(os.path.join('..', '..', 'dataset', 'dataset-ucla-admissions.csv'))

df
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# ..     ...    ...   ...       ...
# 395      0  620.0  4.00       2.0
# 396      0  560.0  3.04       3.0
# 397      0  460.0  2.63       2.0
# 398      0  700.0  3.65       2.0
# 399      0  600.0  3.89       3.0
#
# [400 rows x 4 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
df.columns
# Out:
# Index([u'admit', u'gre', u'gpa', u'prestige'], dtype='object')

# %%
df.isnull().sum().sum()  ###from result: 5 cells are missing values
# Out:
# 5L

# %%
df.isnull().sum() ###checking what cells are missing values
# Out:
# admit       0
# gre         2
# gpa         2
# prestige    1
# dtype: int64

# %%
df[df.admit == 1].count()
# Out:
# admit       127
# gre         127
# gpa         126
# prestige    126
# dtype: int64

# %%
df[df.admit == 0].count()
# Out:
# admit       273
# gre         271
# gpa         272
# prestige    273
# dtype: int64

# %%
max(df.gre)
# Out:
# 800.0

# %%
min(df.gre)
# Out:
# 220.0

# %%
max(df.gpa)
# Out:
# 4.0

# %%
min(df.gpa)
# Out:
# 2.2599999999999998

# %%
min(df.prestige)
# Out:
# 1.0

# %%
max(df.prestige)
# Out:
# 4.0

# %% [markdown]
# > ### Question 5.  Create a data dictionary.

# %% [markdown]
# Answer: TODO
#
# (Use the template below)
#
# Variable | Description | Type of Variable
# ---|---|---
# Var 1 | 0 = Not thing, 1 = Thing | Categorical
# Var 2 | Thing in unit X | Continuous

# %%
admit = [0,1]

# %%
gre = range(200,800)

# %%
dd={admit: {'no':0,'yes':1},
    gre: range (200,800)
   }
print dd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-47b7247f16c7> in <module>()
# ----> 1 dd={admit: {'no':0,'yes':1},
#       2     gre: range (200,800)
#       3    }
#       4 print dd
#
# TypeError: unhashable type: 'list'

# %%
df.to_dict()
# Out:
# {'admit': {0: 0,
#   1: 1,
#   2: 1,
#   3: 1,
#   4: 0,
#   5: 1,
#   6: 1,
#   7: 0,
#   8: 1,
#   9: 0,
#   10: 0,
#   11: 0,
#   12: 1,
#   13: 0,
#   14: 1,
#   15: 0,
#   16: 0,
#   17: 0,
#   18: 0,
#   19: 1,
#   20: 0,
#   21: 1,
#   22: 0,
#   23: 0,
#   24: 1,
#   25: 1,
#   26: 1,
#   27: 1,
#   28: 1,
#   29: 0,
#   30: 0,
#   31: 0,
#   32: 0,
#   33: 1,
#   34: 0,
#   35: 0,
#   36: 0,
#   37: 0,
#   38: 1,
#   39: 1,
#   40: 0,
#   41: 1,
#   42: 1,
#   43: 0,
#   44: 0,
#   45: 1,
#   46: 1,
#   47: 0,
#   48: 0,
#   49: 0,
#   50: 0,
#   51: 0,
#   52: 0,
#   53: 1,
#   54: 0,
#   55: 1,
#   56: 0,
#   57: 0,
#   58: 0,
#   59: 0,
#   60: 1,
#   61: 0,
#   62: 0,
#   63: 1,
#   64: 0,
#   65: 0,
#   66: 0,
#   67: 0,
#   68: 0,
#   69: 0,
#   70: 0,
#   71: 0,
#   72: 0,
#   73: 0,
#   74: 0,
#   75: 0,
#   76: 0,
#   77: 1,
#   78: 0,
#   79: 1,
#   80: 0,
#   81: 0,
#   82: 0,
#   83: 0,
#   84: 1,
#   85: 0,
#   86: 0,
#   87: 0,
#   88: 0,
#   89: 1,
#   90: 0,
# ...

# %%
df[df.admit == 1].gre.mean()
# Out:
# 618.8976377952756

# %%
df[df.admit == 1].gpa.mean()
# Out:
# 3.4892063492063485

# %%
df[df.admit == 1].prestige.mean().groupby('prestige')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f4789e308d97> in <module>()
# ----> 1 df[df.admit == 1].prestige.mean().groupby('prestige')
#
# AttributeError: 'float' object has no attribute 'groupby'

# %%
df[df.admit == 1].gpa.min()
# Out:
# 2.4199999999999999

# %%
df[df.admit == 1].gre.min()
# Out:
# 300.0

# %%
df[df.admit == 1].prestige.min()
# Out:
# 1.0

# %%
df[df.gender == 'Female'].age.median()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
# admit       400 non-null int64
# gre         398 non-null float64
# gpa         398 non-null float64
# prestige    399 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 12.6 KB

# %%
dd[df.to_dict]
dd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e56520dca965> in <module>()
# ----> 1 dd[df.to_dict]
#       2 dd
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __hash__(self)
#     875     def __hash__(self):
#     876         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 877                         ' hashed'.format(self.__class__.__name__))
#     878
#     879     def __iter__(self):
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed

# %% [markdown]
# We would like to explore the association between X and Y.

# %%
df[ ['gre','gpa'] ].boxplot(figsize = (8, 8))

# %% [markdown]
# > ### Question 6.  What is the outcome?

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ### Question 7.  What are the predictors/covariates?

# %% [markdown]
# Answer: GRE,GPA,PRESTIGE

# %% [markdown]
# > ### Question 8.  What timeframe is this data relevent for?

# %% [markdown]
# Answer: during school admission preview

# %% [markdown]
# > ### Question 9.  What is the hypothesis?

# %% [markdown]
# Answer: School admission approval can be made based on application data such as GRE, GPA and prestige of a student

# %% [markdown]
# > ### Question 10.  What's the problem statement?
#
# > Using your answers to the above questions, write a well-formed problem statement.

# %% [markdown]
# Answer:

# %% [markdown]
# ## Part C.  Create an exploratory analysis plan by answering the following questions:

# %% [markdown]
# Because the answers to these questions haven't yet been covered in class yet, this section is optional.  This is by design.  By having you guess or look around for these answers will help make sense once we cover this material in class.  You will not be penalized for wrong answers but we encourage you to give it a try!

# %% [markdown]
# > ### Question 11. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer:
# The primary goal of EDA is to maximize the analyst's insight into a data set and into the underlying structure of a data set, while providing all of the specific items that an analyst would want to extract from a data set, such as:
# a good-fitting, parsimonious model
# a list of outliers
# a sense of robustness of conclusions
# estimates for parameters
# uncertainties for those estimates
# a ranked list of important factors
# conclusions as to whether individual factors are statistically significant
# optimal settings
#
# src: http://www.itl.nist.gov/div898/handbook/eda/section1/eda14.htm

# %% [markdown]
# > ### Question 12.  What are the assumptions of the distribution of data?

# %% [markdown]
# Answer:
# Data will fit some kind of trend and that most things will fit into a "normal" range. This is why we look at measures of central tendency, such as the mean, median and mode, and talk about the normal distribution.

# %% [markdown]
# > ### Question 13.  How will determine the distribution of your data?

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ### Question 14.  How might outliers impact your analysis?

# %% [markdown]
# Answer:
# Outliners affect mostly on the mean and standard deviation of a data set but not so much on mode and median. Outliners can skew or change the shape of the data

# %% [markdown]
# > ### Question 15.  How will you test for outliers?

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ### Question 16.  What is colinearity?

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ### Question 17.  How will you test for covariance?

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ### Question 18.  What is your exploratory analysis plan?
#
# > Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis one year from now.

# %% [markdown]
# Answer: TODO
