# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 20)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import feature_selection, linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('dataset-13-walget-train.csv'))
df
# Out:
#     AccountHolderImpliedGender AccountHolderAddress  \
# 0                       Female                 Home
# 1                       Female               PO Box
# 2                         Male            Apartment
# 3                         Male                 Home
# 4                       Female               PO Box
# ..                         ...                  ...
# 595                       Male                 Home
# 596                     Female                 Home
# 597                       Male            Apartment
# 598                       Male                 Home
# 599                       Male                 Home
#
#     RecentlyPurchasedPregnancyTest RecentlyPurchasedBirthControl  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                          True
# 3                            False                         False
# 4                            False                         False
# ..                             ...                           ...
# 595                          False                         False
# 596                           True                         False
# 597                          False                         False
# 598                          False                         False
# 599                           True                         False
#
#     RecentlyPurchasedFeminineHygieneProducts  \
# 0                                        NaN
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 595                                    False
# 596                                    False
# 597                                    False
# 598                                    False
# 599                                    False
#
#     RecentlyPurchasedFolicAcidSupplements RecentlyPurchasedPrenatalVitamins  \
# 0                                   False                              True
# 1                                   False                             False
# 2                                   False                             False
# 3                                   False                              True
# 4                                   False                             False
# ..                                    ...                               ...
# 595                                 False                             False
# 596                                  True                             False
# 597                                  True                             False
# 598                                 False                             False
# 599                                  True                             False
#
#     RecentlyPurchasedPrenatalYogaDVD RecentlyPurchasedBodyPillow  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                        True
# 4                              False                       False
# ..                               ...                         ...
# 595                            False                       False
# 596                            False                       False
# 597                            False                       False
# 598                            False                       False
# 599                            False                       False
#
#     RecentlyPurchasedGingerAle RecentlyPurchasedSeaBands  \
# 0                        False                      True
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ..                         ...                       ...
# 595                      False                     False
# 596                       True                     False
# 597                      False                     False
# 598                      False                       NaN
# 599                      False                     False
#
#     PurchasedCigarettesRegularlyUntilRecentlyThenStopped  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 595                                              False
# 596                                              False
# 597                                              False
# 598                                              False
# 599                                              False
#
#     RecentlyPurchasedCigarettes RecentlyPurchasedSmokingCessationProducts  \
# 0                         False                                     False
# 1                         False                                     False
# 2                         False                                     False
# 3                         False                                     False
# 4                         False                                     False
# ..                          ...                                       ...
# 595                       False                                       NaN
# 596                       False                                     False
# 597                       False                                     False
# 598                       False                                     False
# 599                       False                                     False
#
#     PurchasedWineRegularlyUntilRecentlyThenStopped RecentlyPurchasedWine  \
# 0                                             True                 False
# 1                                            False                 False
# 2                                            False                 False
# 3                                            False                 False
# 4                                            False                 False
# ..                                             ...                   ...
# 595                                          False                 False
# 596                                          False                 False
# 597                                          False                 False
# 598                                          False                 False
# 599                                          False                 False
#
#     RecentlyPurchasedMaternityClothing  IsPregnant
# 0                                False        True
# 1                                False        True
# 2                                False       False
# 3                                False        True
# 4                                False       False
# ..                                 ...         ...
# 595                              False       False
# 596                              False        True
# 597                              False        True
# 598                              False        True
# 599                               True        True
#
# [600 rows x 18 columns]

# %%
df.sum()
# Out:
# IsPregnant    300
# dtype: int64

# %%
pd.crosstab(df["IsPregnant"], 
                    [df["RecentlyPurchasedSmokingCessationProducts"], df["PurchasedCigarettesRegularlyUntilRecentlyThenStopped"],df["RecentlyPurchasedCigarettes"]])
# Out:
# RecentlyPurchasedSmokingCessationProducts            False             True   \
# PurchasedCigarettesRegularlyUntilRecentlyThenStopped False       True  False
# RecentlyPurchasedCigarettes                          False True  False False
# IsPregnant
# False                                                  225    49    11     3
# True                                                   204    13    36    24
#
# RecentlyPurchasedSmokingCessationProducts
# PurchasedCigarettesRegularlyUntilRecentlyThenStopped       True
# RecentlyPurchasedCigarettes                          True  False
# IsPregnant
# False                                                    0     0
# True                                                     3     7

# %%
pd.crosstab(df["IsPregnant"], 
                    [df["PurchasedWineRegularlyUntilRecentlyThenStopped"],df["RecentlyPurchasedWine"]])
# Out:
# PurchasedWineRegularlyUntilRecentlyThenStopped False       True
# RecentlyPurchasedWine                          False True  False
# IsPregnant
# False                                            224    55    11
# True                                             219     8    64

# %%
cigs_df = pd.get_dummies(df.PurchasedWineRegularlyUntilRecentlyThenStopped, prefix="cigs")

cloth_df = pd.get_dummies(df.RecentlyPurchasedMaternityClothing, prefix="cloth")

birth_df = pd.get_dummies(df.RecentlyPurchasedBirthControl, prefix="birth")

is_df = pd.get_dummies(df.IsPregnant, prefix="prego")

gen_df = pd.get_dummies(df.AccountHolderImpliedGender, prefix="gender")

wine_df = pd.get_dummies(df.PurchasedWineRegularlyUntilRecentlyThenStopped, prefix="wine")

vita_df = pd.get_dummies(df.RecentlyPurchasedPrenatalVitamins, prefix="vita")

cess_df = pd.get_dummies(df.RecentlyPurchasedSmokingCessationProducts, prefix="cess")
