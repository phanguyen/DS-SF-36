# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn import feature_selection, linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('dataset-13-walget-train.csv'))
df
# Out:
#     AccountHolderImpliedGender AccountHolderAddress  \
# 0                       Female                 Home
# 1                       Female               PO Box
# 2                         Male            Apartment
# 3                         Male                 Home
# 4                       Female               PO Box
# ..                         ...                  ...
# 595                       Male                 Home
# 596                     Female                 Home
# 597                       Male            Apartment
# 598                       Male                 Home
# 599                       Male                 Home
#
#     RecentlyPurchasedPregnancyTest RecentlyPurchasedBirthControl  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                          True
# 3                            False                         False
# ...

# %%
df.columns
# Out:
# Index([u'AccountHolderImpliedGender', u'AccountHolderAddress',
#        u'RecentlyPurchasedPregnancyTest', u'RecentlyPurchasedBirthControl',
#        u'RecentlyPurchasedFeminineHygieneProducts',
#        u'RecentlyPurchasedFolicAcidSupplements',
#        u'RecentlyPurchasedPrenatalVitamins',
#        u'RecentlyPurchasedPrenatalYogaDVD', u'RecentlyPurchasedBodyPillow',
#        u'RecentlyPurchasedGingerAle', u'RecentlyPurchasedSeaBands',
#        u'PurchasedCigarettesRegularlyUntilRecentlyThenStopped',
#        u'RecentlyPurchasedCigarettes',
#        u'RecentlyPurchasedSmokingCessationProducts',
#        u'PurchasedWineRegularlyUntilRecentlyThenStopped',
#        u'RecentlyPurchasedWine', u'RecentlyPurchasedMaternityClothing',
#        u'IsPregnant'],
#       dtype='object')

# %%
df.count()
# Out:
# AccountHolderImpliedGender                        542
# AccountHolderAddress                              594
# RecentlyPurchasedPregnancyTest                    594
# RecentlyPurchasedBirthControl                     593
# RecentlyPurchasedFeminineHygieneProducts          590
#                                                  ...
# RecentlyPurchasedSmokingCessationProducts         588
# PurchasedWineRegularlyUntilRecentlyThenStopped    588
# RecentlyPurchasedWine                             592
# RecentlyPurchasedMaternityClothing                597
# IsPregnant                                        600
# Length: 18, dtype: int64

# %%
from IPython.display import Image
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.datasets import make_classification;
# Out:
# /Users/maxie/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df = df.drop('AccountHolderImpliedGender',1)
df
# Out:
#     RecentlyPurchasedPregnancyTest RecentlyPurchasedBirthControl  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                          True
# 3                            False                         False
# 4                            False                         False
# ..                             ...                           ...
# 595                          False                         False
# 596                           True                         False
# 597                          False                         False
# 598                          False                         False
# 599                           True                         False
#
#     RecentlyPurchasedFeminineHygieneProducts  \
# 0                                        NaN
# 1                                      False
# 2                                      False
# ...

# %%
df
# Out:
#     AccountHolderImpliedGender RecentlyPurchasedPregnancyTest  \
# 0                       Female                          False
# 1                       Female                          False
# 2                         Male                          False
# 3                         Male                          False
# 4                       Female                          False
# ..                         ...                            ...
# 595                       Male                          False
# 596                     Female                           True
# 597                       Male                          False
# 598                       Male                          False
# 599                       Male                           True
#
#     RecentlyPurchasedBirthControl RecentlyPurchasedFeminineHygieneProducts  \
# 0                           False                                      NaN
# ...

# %%
AccountHolderImpliedGender

# %%
X = df.drop("IsPregnant", axis=1)
y = df.IsPregnant

#Intialize, fit, and score the model
lr = LogisticRegression()

lr.fit(X,y)

score = lr.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-330c08bafc64> in <module>()
#       5 lr = LogisticRegression()
#       6
# ----> 7 lr.fit(X,y)
#       8
#       9 score = lr.score(X,y)
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
df.dropna()
# Out:
#     RecentlyPurchasedPregnancyTest RecentlyPurchasedBirthControl  \
# 1                            False                         False
# 2                            False                          True
# 3                            False                         False
# 4                            False                         False
# 5                            False                          True
# ..                             ...                           ...
# 592                          False                         False
# 593                          False                         False
# 596                           True                         False
# 597                          False                         False
# 599                           True                         False
#
#     RecentlyPurchasedFeminineHygieneProducts  \
# 1                                      False
# 2                                      False
# 3                                      False
# ...

# %%
df
# Out:
#     AccountHolderImpliedGender AccountHolderAddress  \
# 0                       Female                 Home
# 1                       Female               PO Box
# 2                         Male            Apartment
# 3                         Male                 Home
# 4                       Female               PO Box
# ..                         ...                  ...
# 595                       Male                 Home
# 596                     Female                 Home
# 597                       Male            Apartment
# 598                       Male                 Home
# 599                       Male                 Home
#
#     RecentlyPurchasedPregnancyTest RecentlyPurchasedBirthControl  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                          True
# 3                            False                         False
# ...

# %%
Gender_Df = pd.get_dummies(df.AccountHolderImpliedGender,prefix = 'Gender')
Gender_Df
# Out:
#      Gender_Female  Gender_Male
# 0                1            0
# 1                1            0
# 2                0            1
# 3                0            1
# 4                1            0
# ..             ...          ...
# 595              0            1
# 596              1            0
# 597              0            1
# 598              0            1
# 599              0            1
#
# [600 rows x 2 columns]

# %%
pd.crosstab(df["IsPregnant"], 
                    [df["RecentlyPurchasedPregnancyTest"], df["RecentlyPurchasedBirthControl"]])
# Out:
# RecentlyPurchasedPregnancyTest False       True
# RecentlyPurchasedBirthControl  False True  False True
# IsPregnant
# False                            220    68     2     2
# True                             249     6    40     1

# %%
Ptest_df = pd.get_dummies(df.RecentlyPurchasedPregnancyTest,prefix = 'PTest')
Ptest_df
# Out:
#      PTest_False  PTest_True
# 0              1           0
# 1              1           0
# 2              1           0
# 3              1           0
# 4              1           0
# ..           ...         ...
# 595            1           0
# 596            0           1
# 597            1           0
# 598            1           0
# 599            0           1
#
# [600 rows x 2 columns]

# %%
df.drop('AccountHolderAddress',1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-b04b3c9a80fe> in <module>()
# ----> 1 df.drop('AccountHolderAddress',1)
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
#    3576             indexer = indexer[~mask]
# ...

# %%
df
# Out:
#     AccountHolderImpliedGender RecentlyPurchasedPregnancyTest  \
# 0                       Female                          False
# 1                       Female                          False
# 2                         Male                          False
# 3                         Male                          False
# 4                       Female                          False
# ..                         ...                            ...
# 595                       Male                          False
# 596                     Female                           True
# 597                       Male                          False
# 598                       Male                          False
# 599                       Male                           True
#
#     RecentlyPurchasedBirthControl RecentlyPurchasedFeminineHygieneProducts  \
# 0                           False                                      NaN
# ...

# %%
pd.crosstab(df.IsPregnant,df.RecentlyPurchasedFeminineHygieneProducts,dropna = False)
# Out:
# RecentlyPurchasedFeminineHygieneProducts  False  True
# IsPregnant
# False                                       227     71
# True                                        275     17

# %%
df.corr(df.IsPregnant,df.RecentlyPurchasedFeminineHygieneProducts)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-b9d2ff8060ea> in <module>()
# ----> 1 df.corr(df.IsPregnant,df.RecentlyPurchasedFeminineHygieneProducts)
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in corr(self, method, min_periods)
#    4937         mat = numeric_df.values
#    4938
# -> 4939         if method == 'pearson':
#    4940             correl = libalgos.nancorr(_ensure_float64(mat), minp=min_periods)
#    4941         elif method == 'spearman':
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# ...

# %%
smf.ols(formula = 'IsPregnant ~ ', data = df).fit().summary()
# Out:
#   File "<ipython-input-23-153bcce97528>", line 1
#     smf.ols(formula = smf.ols(formula = 'IsPregnant' ~ 'RecentlyPurchasedPregnancyTest', data = df).fit().summary(), data = df).fit().summary()
#                                                      ^
# SyntaxError: invalid syntax

# %%
X = df.values[:,1:]
y = df.values[:,0:]
X_train,X_Test,y_train,y_test = train_test_split(X,y,test_size = 3, random_State = 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2adb9f328792> in <module>()
#       1 X = df.values[:,1:]
#       2 y = df.values[:,0:]
# ----> 3 X_train,X_Test,y_train,y_test = train_test_split(X,y,test_size = 3, random_State = 4)
#
# NameError: name 'train_test_split' is not defined

# %%
train_df = df.sample(frac=.7,random_state=4).sort_index()

# %%
test_df = df.drop(train_df.index)

# %%
train_df['y'] = train_df.IsPregnant
train_df['x'] = train_df.RecentlyPurchasedFeminineHygieneProducts

# %%
def X_linear (df):
    X = df[['x']]
    return X

model = linear_model.LinearRegression().fit(X_linear(train_df),train_df.y)


print model_linear.intercept_
print model_linear.coef_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-4a81a6ba39f0> in <module>()
#       3     return X
#       4
# ----> 5 model = linear_model.LinearRegression().fit(X_linear(train_df),train_df.y)
#       6
#       7
#
# /Users/maxie/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     510         n_jobs_ = self.n_jobs
#     511         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 512                          y_numeric=True, multi_output=True)
#     513
#     514         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
df.IsPregnant.groupby(df.AccountHolderImpliedGender)
